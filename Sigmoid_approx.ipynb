# %% [markdown]
# # Sigmoid approximation with Legendre

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5.78, 5.78, 100)
sig_org = 1./(1+np.exp(-1*x))
#sig_aprox = 0.0003947105*(x**5) - 0.01234797628700*(x**3) + 0.23522282122*(x**5) + 0.5
#sig_aprox = - 0.0000047530703794746094298298225472514*(x**7) + 5.0418246026598074059404996017332e-37*(x**6) + 0.00039471059751463464848499684737176*(x**5) - 2.3064728970340823514177163310742e-35*(x**4) - 0.012347976287004582119276719308383*(x**3) + 2.4507132796015027058278551576234e-34*(x**2) + 0.23522282122075508280345817919386*x + 0.5
sig_aprox = - 0.000004753*(x**7) + 0.0003947106*(x**5) - 0.012347976287*(x**3) + 0.2352228212208*x + 0.5
plt.plot(x,sig_org)
plt.plot(x,sig_aprox)
